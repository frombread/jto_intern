# %%
import pandas as pd
df= pd.read_csv(r'C:\Users\user\Desktop\제주 우도6_1.csv',encoding='cp949')

# %%
df1=df.groupby("w").sum()
df1=df1.reset_index()
df1=df1.sort_values(by="z",ascending=False)

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import pandas as pd
plt.rcParams['font.family'] ='Malgun Gothic'
plt.rcParams['axes.unicode_minus'] =False
wc = WordCloud(font_path='malgun',background_color='white')

frq = df.set_index("w").to_dict()["z"]
keyword=wc.generate_from_frequencies(frq)
plt.figure(figsize=(10,10))
plt.imshow(keyword)
plt.axis("off")
# Out:
# (-0.5, 399.5, 199.5, -0.5)
